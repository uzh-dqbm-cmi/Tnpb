# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import numpy as np
import pandas as pd
import torch
import argparse
from models.data_process import get_datatensor_partitions, prepare_nonproto_features, generate_partition_datatensor
from models.dataset import ProtospacerDataset, ProtospacerExtendedDataset
from src.utils import create_directory, one_hot_encode, get_device, ReaderWriter, print_eval_results
import matplotlib.pyplot as plt

# %%
cmd_opt = argparse.ArgumentParser(description='Argparser for data')
cmd_opt.add_argument('-model_name',  type=str, help = 'name of the model')
cmd_opt.add_argument('-exp_name',  type=str, help = 'name of the experiment')

cmd_opt.add_argument('-data_dir',  type=str,default = './data/', help = 'directory of the data')
cmd_opt.add_argument('-target_dir',  type=str, default='processed',  help = 'folder name to save the processed data')
cmd_opt.add_argument('-working_dir',  type=str, default='./', help = 'the main working directory')
cmd_opt.add_argument('-output_path', type=str, help='path to save the trained model')
cmd_opt.add_argument('-model_path', type=str, help='path to trained model')
cmd_opt.add_argument('-random_seed', type=int,default=42)
cmd_opt.add_argument('-epoch_num', type=int, default =200, help='number of training epochs')
args, _ = cmd_opt.parse_known_args()

# %%
def get_data_ready(args, normalize_opt = 'max', train_size=0.9, fdtype=torch.float32):
    ## prepare the data
    data_dir = args.data_dir + args.target_dir
    data_partitions = ReaderWriter.read_data(data_dir + '/data_partitions.pkl')
    data = ReaderWriter.read_data(data_dir + '/list_of_x_f_y.pkl')
    x_protospacer, x_extended_f,x_non_protos_f, y = data

    if args.model_name in {'CNN', 'FFN'}:
        ## onehot-encode the protospacer features
        proc_x_protospacer = one_hot_encode(x_protospacer)
        proc_x_protospacer = proc_x_protospacer.reshape(proc_x_protospacer.shape[0], -1)
    elif args.model_name in {'Transformer', 'RNN'}:
        proc_x_protospacer = x_protospacer 
        
    x_non_protos_f_df, x_non_protos_f_norm = prepare_nonproto_features(x_non_protos_f, normalize_opt)
    
    if args.exp_name == 'protospacer_extended':
        x_non_protos_features = x_non_protos_f_norm
    elif args.exp_name == 'protospacer':
        x_non_protos_features = None
    dpartitions, datatensor_partitions = get_datatensor_partitions(data_partitions,
                                                                   args.model_name,
                                                                   proc_x_protospacer,
                                                                   y,
                                                                   x_non_protos_features,
                                                                   fdtype=fdtype,
                                                                   train_size=train_size,
                                                                   random_state=args.random_seed)
    return dpartitions, datatensor_partitions

# %% [markdown]
# ### Run trained models and evaluate performance on test set

# %%
from models.trainval_workflow import run_inference
from src.utils import compute_eval_results_df

# %%
gpu_index = 0
res_desc = {}
version=2
for model_name in ['FFN', 'CNN', 'RNN', 'Transformer']:
    args.model_name =  model_name# {'RNN','CNN', 'Transformer'}
    res_desc[model_name] = {}
    for exp_name in ['protospacer', 'protospacer_extended']:
        args.exp_name = exp_name
        model_path = os.path.join(args.working_dir, 
                                  'output', 
                                  f'{model_name}_v{version}',
                                  exp_name)
        dpartitions, datatensor_partitions = get_data_ready(args, 
                                                            normalize_opt='max',
                                                            train_size=0.9, 
                                                            fdtype=torch.float32)

        train_val_path = os.path.join(model_path, 'train_val')
        test_path = os.path.join(model_path, 'test')
        
        print(f'Running model: {model_name}, exp_name: {exp_name}, saved at {train_val_path}')
        a, b = run_inference(datatensor_partitions, 
                             train_val_path, 
                             test_path, 
                             gpu_index, 
                             to_gpu=True)
        print('='*15)
        res_desc[model_name][exp_name] = compute_eval_results_df(test_path, len(dpartitions))
# Out:
# --- max normalization ---
# we are here
# Running model: FFN, exp_name: protospacer, saved at ./output/FFN_v2/protospacer/train_val
# cuda:0
# test
# number of epochs 1
# model_name: FFN
# input_size: 20
# did not intialized
# Epoch: 0
# Regression report on all events:
# MAE:
# 4.3219873533201225
# MSE:
# 38.48578779227363
# Correlation coefficient:
# 0.7681327170779785
# Spearman coefficient:
# 0.7098378765483445
# Pearson coefficient:
# 0.7681327170779781
# ------------------------------
#
# xxxxxxxxxxxxxxxxxxxxxxxxx
# test
# number of epochs 1
# model_name: FFN
# input_size: 20
# did not intialized
# Epoch: 0
# Regression report on all events:
# MAE:
# 4.451395072344548
# MSE:
# 40.14511364493444
# Correlation coefficient:
# 0.765096645354447
# Spearman coefficient:
# 0.7331969400465593
# Pearson coefficient:
# 0.7650966453544472
# ------------------------------
#
# xxxxxxxxxxxxxxxxxxxxxxxxx
# test
# number of epochs 1
# model_name: FFN
# input_size: 20
# did not intialized
# Epoch: 0
# Regression report on all events:
# MAE:
# 4.273986512010915
# MSE:
# 37.95597700837563
# Correlation coefficient:
# 0.7453081706571402
# Spearman coefficient:
# 0.7192276087655324
# Pearson coefficient:
# 0.7453081706571402
# ------------------------------
#
# xxxxxxxxxxxxxxxxxxxxxxxxx
# test
# number of epochs 1
# model_name: FFN
# input_size: 20
# did not intialized
# Epoch: 0
# Regression report on all events:
# MAE:
# 4.441211134629671
# MSE:
# 42.48534463014874
# Correlation coefficient:
# 0.7401682425572944
# Spearman coefficient:
# 0.7175081948191552
# Pearson coefficient:
# 0.7401682425572949
# ------------------------------
#
# xxxxxxxxxxxxxxxxxxxxxxxxx
# test
# number of epochs 1
# model_name: FFN
# input_size: 20
# did not intialized
# Epoch: 0
# Regression report on all events:
# MAE:
# 4.413304100994516
# MSE:
# 39.8391869149325
# Correlation coefficient:
# 0.735278496287458
# Spearman coefficient:
# 0.69936664880441
# Pearson coefficient:
# 0.7352784962874581
# ------------------------------
#
# xxxxxxxxxxxxxxxxxxxxxxxxx
# ===============
# run_name: run_0
# run_name: run_1
# run_name: run_2
# run_name: run_3
# run_name: run_4
# --- max normalization ---
# we are here
# Running model: FFN, exp_name: protospacer_extended, saved at ./output/FFN_v2/protospacer_extended/train_val
# cuda:0
# test
# number of epochs 1
# model_name: FFN
# input_size: 30
# did not intialized
# did not intialized
# did not intialized
# did not intialized
# did not intialized
# did not intialized
# did not intialized
# did not intialized
# Epoch: 0
# Regression report on all events:
# MAE:
# 4.126849077872281
# MSE:
# 36.57604163322679
# Correlation coefficient:
# 0.7846373657402625
# Spearman coefficient:
# 0.7377130425450766
# Pearson coefficient:
# 0.7846373657402627
# ------------------------------
#
# xxxxxxxxxxxxxxxxxxxxxxxxx
# test
# number of epochs 1
# model_name: FFN
# input_size: 30
# did not intialized
# did not intialized
# did not intialized
# did not intialized
# did not intialized
# did not intialized
# did not intialized
# did not intialized
# Epoch: 0
# Regression report on all events:
# MAE:
# 4.057595111431519
# MSE:
# 35.01034115033584
# Correlation coefficient:
# 0.7785627673499966
# Spearman coefficient:
# 0.7433252024942134
# Pearson coefficient:
# 0.7785627673499965
# ------------------------------
#
# xxxxxxxxxxxxxxxxxxxxxxxxx
# test
# number of epochs 1
# model_name: FFN
# input_size: 30
# did not intialized
# did not intialized
# did not intialized
# did not intialized
# did not intialized
# did not intialized
# did not intialized
# did not intialized
# Epoch: 0
# Regression report on all events:
# MAE:
# 4.278762770204333
# MSE:
# 37.498305217939034
# Correlation coefficient:
# 0.7452028693831012
# Spearman coefficient:
# 0.7127113540858309
# Pearson coefficient:
# 0.7452028693831015
# ------------------------------
#
# xxxxxxxxxxxxxxxxxxxxxxxxx
# test
# number of epochs 1
# model_name: FFN
# input_size: 30
# did not intialized
# did not intialized
# did not intialized
# did not intialized
# did not intialized
# did not intialized
# did not intialized
# did not intialized
# Epoch: 0
# Regression report on all events:
# MAE:
# 4.311937738905826
# MSE:
# 41.85892562373052
# Correlation coefficient:
# 0.748264445223089
# Spearman coefficient:
# 0.7256442326348989
# Pearson coefficient:
# 0.7482644452230889
# ------------------------------
#
# xxxxxxxxxxxxxxxxxxxxxxxxx
# test
# number of epochs 1
# model_name: FFN
# input_size: 30
# did not intialized
# did not intialized
# did not intialized
# did not intialized
# did not intialized
# did not intialized
# did not intialized
# did not intialized
# Epoch: 0
# Regression report on all events:
# MAE:
# 4.421915455640394
# MSE:
# 41.611456300108046
# Correlation coefficient:
# 0.7351718269470633
# Spearman coefficient:
# 0.7132331248644915
# Pearson coefficient:
# 0.7351718269470631
# ------------------------------
#
# xxxxxxxxxxxxxxxxxxxxxxxxx
# ===============
# run_name: run_0
# run_name: run_1
# run_name: run_2
# run_name: run_3
# run_name: run_4
# --- max normalization ---
# we are here
# Running model: CNN, exp_name: protospacer, saved at ./output/CNN_v2/protospacer/train_val
# cuda:0
# test
# number of epochs 1
# model_name: CNN
# input_size: 20
# Epoch: 0
# Regression report on all events:
# MAE:
# 3.7037954104166766
# MSE:
# 29.9829402796003
# Correlation coefficient:
# 0.8292581593998313
# Spearman coefficient:
# 0.7690193217308771
# Pearson coefficient:
# 0.8292581593998309
# ------------------------------
#
# xxxxxxxxxxxxxxxxxxxxxxxxx
# test
# number of epochs 1
# model_name: CNN
# input_size: 20
# Epoch: 0
# Regression report on all events:
# MAE:
# 3.7408523802920604
# MSE:
# 30.76253416461362
# Correlation coefficient:
# 0.8118679933165179
# Spearman coefficient:
# 0.7890194951874849
# Pearson coefficient:
# 0.8118679933165179
# ------------------------------
#
# xxxxxxxxxxxxxxxxxxxxxxxxx
# test
# number of epochs 1
# model_name: CNN
# input_size: 20
# Epoch: 0
# Regression report on all events:
# MAE:
# 4.105557636731652
# MSE:
# 33.566012418508265
# Correlation coefficient:
# 0.7934314026295483
# Spearman coefficient:
# 0.7633187794821559
# Pearson coefficient:
# 0.793431402629548
# ------------------------------
#
# xxxxxxxxxxxxxxxxxxxxxxxxx
# test
# number of epochs 1
# model_name: CNN
# input_size: 20
# Epoch: 0
# Regression report on all events:
# MAE:
# 3.915195554347638
# MSE:
# 33.71986788422329
# Correlation coefficient:
# 0.8043719423525151
# Spearman coefficient:
# 0.7716244543928082
# Pearson coefficient:
# 0.804371942352515
# ------------------------------
#
# xxxxxxxxxxxxxxxxxxxxxxxxx
# test
# number of epochs 1
# model_name: CNN
# input_size: 20
# Epoch: 0
# Regression report on all events:
# MAE:
# 3.7663879239237668
# MSE:
# 28.97762398763328
# Correlation coefficient:
# 0.8010980415862599
# Spearman coefficient:
# 0.7582490875700498
# Pearson coefficient:
# 0.8010980415862596
# ------------------------------
#
# xxxxxxxxxxxxxxxxxxxxxxxxx
# ===============
# run_name: run_0
# run_name: run_1
# run_name: run_2
# run_name: run_3
# run_name: run_4
# --- max normalization ---
# we are here
# Running model: CNN, exp_name: protospacer_extended, saved at ./output/CNN_v2/protospacer_extended/train_val
# cuda:0
# test
# number of epochs 1
# model_name: CNN
# input_size: 30
# Epoch: 0
# Regression report on all events:
# MAE:
# 3.8083753090103225
# MSE:
# 29.985961246935187
# Correlation coefficient:
# 0.8253345492627745
# Spearman coefficient:
# 0.7642764227467157
# Pearson coefficient:
# 0.8253345492627747
# ------------------------------
#
# xxxxxxxxxxxxxxxxxxxxxxxxx
# test
# number of epochs 1
# model_name: CNN
# input_size: 30
# Epoch: 0
# Regression report on all events:
# MAE:
# 3.7523600191217907
# MSE:
# 29.354767367215377
# Correlation coefficient:
# 0.8180673983565607
# Spearman coefficient:
# 0.7838189605251482
# Pearson coefficient:
# 0.8180673983565606
# ------------------------------
#
# xxxxxxxxxxxxxxxxxxxxxxxxx
# test
# number of epochs 1
# model_name: CNN
# input_size: 30
# Epoch: 0
# Regression report on all events:
# MAE:
# 3.845841788278273
# MSE:
# 30.387537736683086
# Correlation coefficient:
# 0.7947892124537189
# Spearman coefficient:
# 0.7649060855583031
# Pearson coefficient:
# 0.7947892124537188
# ------------------------------
#
# xxxxxxxxxxxxxxxxxxxxxxxxx
# test
# number of epochs 1
# model_name: CNN
# input_size: 30
# Epoch: 0
# Regression report on all events:
# MAE:
# 3.9319956495317325
# MSE:
# 33.969576442762246
# Correlation coefficient:
# 0.8002727620704101
# Spearman coefficient:
# 0.7710276048924647
# Pearson coefficient:
# 0.8002727620704099
# ------------------------------
#
# xxxxxxxxxxxxxxxxxxxxxxxxx
# test
# number of epochs 1
# model_name: CNN
# input_size: 30
# Epoch: 0
# Regression report on all events:
# MAE:
# 3.737352482192712
# MSE:
# 28.837177891873555
# Correlation coefficient:
# 0.8022151594594296
# Spearman coefficient:
# 0.7608427322770642
# Pearson coefficient:
# 0.8022151594594294
# ------------------------------
#
# xxxxxxxxxxxxxxxxxxxxxxxxx
# ===============
# run_name: run_0
# run_name: run_1
# run_name: run_2
# run_name: run_3
# run_name: run_4
# --- max normalization ---
# Running model: RNN, exp_name: protospacer, saved at ./output/RNN_v2/protospacer/train_val
# cuda:0
# test
# number of epochs 1
# model_name: RNN
# input_size: 20
# Epoch: 0
# Regression report on all events:
# MAE:
# 3.7811233700720104
# MSE:
# 31.446797731830046
# Correlation coefficient:
# 0.8172009905174675
# Spearman coefficient:
# 0.7722280355873233
# Pearson coefficient:
# 0.8172009905174672
# ------------------------------
#
# xxxxxxxxxxxxxxxxxxxxxxxxx
# test
# number of epochs 1
# model_name: RNN
# input_size: 20
# Epoch: 0
# Regression report on all events:
# MAE:
# 3.806989899033112
# MSE:
# 31.11571614095497
# Correlation coefficient:
# 0.8112474627971671
# Spearman coefficient:
# 0.7823814142776335
# Pearson coefficient:
# 0.8112474627971675
# ------------------------------
#
# xxxxxxxxxxxxxxxxxxxxxxxxx
# test
# number of epochs 1
# model_name: RNN
# input_size: 20
# Epoch: 0
# Regression report on all events:
# MAE:
# 3.835496518280178
# MSE:
# 31.206768682690985
# Correlation coefficient:
# 0.7900412826046883
# Spearman coefficient:
# 0.7732016044903951
# Pearson coefficient:
# 0.7900412826046881
# ------------------------------
#
# xxxxxxxxxxxxxxxxxxxxxxxxx
# test
# number of epochs 1
# model_name: RNN
# input_size: 20
# Epoch: 0
# Regression report on all events:
# MAE:
# 3.9563654109252235
# MSE:
# 33.85109800439548
# Correlation coefficient:
# 0.8009078737162028
# Spearman coefficient:
# 0.765912830086012
# Pearson coefficient:
# 0.8009078737162023
# ------------------------------
#
# xxxxxxxxxxxxxxxxxxxxxxxxx
# test
# number of epochs 1
# model_name: RNN
# input_size: 20
# Epoch: 0
# Regression report on all events:
# MAE:
# 3.6317481633337927
# MSE:
# 27.721470674466936
# Correlation coefficient:
# 0.8091416661929492
# Spearman coefficient:
# 0.7643496451118313
# Pearson coefficient:
# 0.8091416661929495
# ------------------------------
#
# xxxxxxxxxxxxxxxxxxxxxxxxx
# ===============
# run_name: run_0
# run_name: run_1
# run_name: run_2
# run_name: run_3
# run_name: run_4
# --- max normalization ---
# Running model: RNN, exp_name: protospacer_extended, saved at ./output/RNN_v2/protospacer_extended/train_val
# cuda:0
# test
# number of epochs 1
# model_name: RNN
# input_size: 30
# Epoch: 0
# Regression report on all events:
# MAE:
# 3.782751423330526
# MSE:
# 31.54574153094641
# Correlation coefficient:
# 0.815824199530457
# Spearman coefficient:
# 0.7698320795414714
# Pearson coefficient:
# 0.8158241995304572
# ------------------------------
#
# xxxxxxxxxxxxxxxxxxxxxxxxx
# test
# number of epochs 1
# model_name: RNN
# input_size: 30
# Epoch: 0
# Regression report on all events:
# MAE:
# 3.8806682028867105
# MSE:
# 31.846691169106812
# Correlation coefficient:
# 0.8038861021942059
# Spearman coefficient:
# 0.7788469218796197
# Pearson coefficient:
# 0.8038861021942062
# ------------------------------
#
# xxxxxxxxxxxxxxxxxxxxxxxxx
# test
# number of epochs 1
# model_name: RNN
# input_size: 30
# Epoch: 0
# Regression report on all events:
# MAE:
# 3.98146446486999
# MSE:
# 33.03054182911936
# Correlation coefficient:
# 0.780654237555269
# Spearman coefficient:
# 0.7537578458803932
# Pearson coefficient:
# 0.7806542375552687
# ------------------------------
#
# xxxxxxxxxxxxxxxxxxxxxxxxx
# test
# number of epochs 1
# model_name: RNN
# input_size: 30
# Epoch: 0
# Regression report on all events:
# MAE:
# 4.2647817442545675
# MSE:
# 44.24650929076382
# Correlation coefficient:
# 0.7562253486008084
# Spearman coefficient:
# 0.7509289105896014
# Pearson coefficient:
# 0.7562253486008079
# ------------------------------
#
# xxxxxxxxxxxxxxxxxxxxxxxxx
# test
# number of epochs 1
# model_name: RNN
# input_size: 30
# Epoch: 0
# Regression report on all events:
# MAE:
# 3.5344929264745892
# MSE:
# 27.863923795455293
# Correlation coefficient:
# 0.8097444098406954
# Spearman coefficient:
# 0.7689219124764429
# Pearson coefficient:
# 0.8097444098406952
# ------------------------------
#
# xxxxxxxxxxxxxxxxxxxxxxxxx
# ===============
# run_name: run_0
# run_name: run_1
# run_name: run_2
# run_name: run_3
# run_name: run_4
# --- max normalization ---
# Running model: Transformer, exp_name: protospacer, saved at ./output/Transformer_v2/protospacer/train_val
# cuda:0
# test
# number of epochs 1
# model_name: Transformer
# input_size: 20
# Epoch: 0
# Regression report on all events:
# MAE:
# 4.61411447185471
# MSE:
# 42.03073168673404
# Correlation coefficient:
# 0.7488776885124414
# Spearman coefficient:
# 0.6824838130373375
# Pearson coefficient:
# 0.7488776885124414
# ------------------------------
#
# xxxxxxxxxxxxxxxxxxxxxxxxx
# test
# number of epochs 1
# model_name: Transformer
# input_size: 20
# Epoch: 0
# Regression report on all events:
# MAE:
# 4.626415345947586
# MSE:
# 41.11321019711804
# Correlation coefficient:
# 0.7551785799786895
# Spearman coefficient:
# 0.7034732072189763
# Pearson coefficient:
# 0.7551785799786896
# ------------------------------
#
# xxxxxxxxxxxxxxxxxxxxxxxxx
# test
# number of epochs 1
# model_name: Transformer
# input_size: 20
# Epoch: 0
# Regression report on all events:
# MAE:
# 4.349096957859204
# MSE:
# 37.640830548466504
# Correlation coefficient:
# 0.7419847050779936
# Spearman coefficient:
# 0.6952627681030641
# Pearson coefficient:
# 0.7419847050779933
# ------------------------------
#
# xxxxxxxxxxxxxxxxxxxxxxxxx
# test
# number of epochs 1
# model_name: Transformer
# input_size: 20
# Epoch: 0
# Regression report on all events:
# MAE:
# 4.427823765097286
# MSE:
# 41.621910813081186
# Correlation coefficient:
# 0.7455977750513764
# Spearman coefficient:
# 0.7247800168063289
# Pearson coefficient:
# 0.7455977750513765
# ------------------------------
#
# xxxxxxxxxxxxxxxxxxxxxxxxx
# test
# number of epochs 1
# model_name: Transformer
# input_size: 20
# Epoch: 0
# Regression report on all events:
# MAE:
# 4.2539497184840105
# MSE:
# 37.351835628907004
# Correlation coefficient:
# 0.7353574088521139
# Spearman coefficient:
# 0.6906163137598236
# Pearson coefficient:
# 0.7353574088521139
# ------------------------------
#
# xxxxxxxxxxxxxxxxxxxxxxxxx
# ===============
# run_name: run_0
# run_name: run_1
# run_name: run_2
# run_name: run_3
# run_name: run_4
# --- max normalization ---
# Running model: Transformer, exp_name: protospacer_extended, saved at ./output/Transformer_v2/protospacer_extended/train_val
# cuda:0
# test
# number of epochs 1
# model_name: Transformer
# input_size: 30
# Epoch: 0
# Regression report on all events:
# MAE:
# 4.26643205523469
# MSE:
# 37.464300754695
# Correlation coefficient:
# 0.7796587076252186
# Spearman coefficient:
# 0.7190988102794349
# Pearson coefficient:
# 0.7796587076252187
# ------------------------------
#
# xxxxxxxxxxxxxxxxxxxxxxxxx
# test
# number of epochs 1
# model_name: Transformer
# input_size: 30
# Epoch: 0
# Regression report on all events:
# MAE:
# 4.219082214473815
# MSE:
# 37.45022627076002
# Correlation coefficient:
# 0.7611877814671278
# Spearman coefficient:
# 0.7284553597002338
# Pearson coefficient:
# 0.7611877814671281
# ------------------------------
#
# xxxxxxxxxxxxxxxxxxxxxxxxx
# test
# number of epochs 1
# model_name: Transformer
# input_size: 30
# Epoch: 0
# Regression report on all events:
# MAE:
# 4.139365179263151
# MSE:
# 34.189068117694404
# Correlation coefficient:
# 0.7656370890846093
# Spearman coefficient:
# 0.7217725973908271
# Pearson coefficient:
# 0.7656370890846095
# ------------------------------
#
# xxxxxxxxxxxxxxxxxxxxxxxxx
# test
# number of epochs 1
# model_name: Transformer
# input_size: 30
# Epoch: 0
# Regression report on all events:
# MAE:
# 4.481316612113521
# MSE:
# 45.483317048937096
# Correlation coefficient:
# 0.7322726359370147
# Spearman coefficient:
# 0.7081786127783241
# Pearson coefficient:
# 0.7322726359370149
# ------------------------------
#
# xxxxxxxxxxxxxxxxxxxxxxxxx
# test
# number of epochs 1
# model_name: Transformer
# input_size: 30
# Epoch: 0
# Regression report on all events:
# MAE:
# 4.076254330250852
# MSE:
# 35.27679032954149
# Correlation coefficient:
# 0.7503743646763346
# Spearman coefficient:
# 0.7069919999822974
# Pearson coefficient:
# 0.7503743646763348
# ------------------------------
#
# xxxxxxxxxxxxxxxxxxxxxxxxx
# ===============
# run_name: run_0
# run_name: run_1
# run_name: run_2
# run_name: run_3
# run_name: run_4

# %%
for model_name in res_desc:
    for exp_name in res_desc[model_name]:
        print(f'model_name: {model_name}, exp_name: {exp_name}')
        display(res_desc[model_name][exp_name])
        print('='*15)
# Out:
# model_name: FFN, exp_name: protospacer
#              run_0     run_1     run_2     run_3     run_4      mean  \
# spearman  0.709838  0.733197  0.719228  0.717508  0.699367  0.715827
# pearson   0.768133  0.765097  0.745308  0.740168  0.735278  0.750797
# MAE       4.321987  4.451395  4.273987  4.441211  4.413304  4.380377
#
#             median    stddev
# spearman  0.717508  0.012479
# pearson   0.745308  0.014907
# MAE       4.413304  0.078353
# ===============
# model_name: FFN, exp_name: protospacer_extended
#              run_0     run_1     run_2     run_3     run_4      mean  \
# spearman  0.737713  0.743325  0.712711  0.725644  0.713233  0.726525
# pearson   0.784637  0.778563  0.745203  0.748264  0.735172  0.758368
# MAE       4.126849  4.057595  4.278763  4.311938  4.421915  4.239412
#
#             median    stddev
# spearman  0.725644  0.013926
# pearson   0.748264  0.021860
# MAE       4.278763  0.146496
# ===============
# model_name: CNN, exp_name: protospacer
#              run_0     run_1     run_2     run_3     run_4      mean  \
# spearman  0.769019  0.789019  0.763319  0.771624  0.758249  0.770246
# pearson   0.829258  0.811868  0.793431  0.804372  0.801098  0.808006
# MAE       3.703795  3.740852  4.105558  3.915196  3.766388  3.846358
#
#             median    stddev
# spearman  0.769019  0.011702
# pearson   0.804372  0.013601
# MAE       3.766388  0.165661
# ===============
# model_name: CNN, exp_name: protospacer_extended
#              run_0     run_1     run_2     run_3     run_4      mean  \
# spearman  0.764276  0.783819  0.764906  0.771028  0.760843  0.768974
# pearson   0.825335  0.818067  0.794789  0.800273  0.802215  0.808136
# MAE       3.808375  3.752360  3.845842  3.931996  3.737352  3.815185
#
#             median    stddev
# spearman  0.764906  0.009074
# pearson   0.802215  0.012937
# MAE       3.808375  0.078479
# ===============
# model_name: RNN, exp_name: protospacer
#              run_0     run_1     run_2     run_3     run_4      mean  \
# spearman  0.772228  0.782381  0.773202  0.765913  0.764350  0.771615
# pearson   0.817201  0.811247  0.790041  0.800908  0.809142  0.805708
# MAE       3.781123  3.806990  3.835497  3.956365  3.631748  3.802345
#
#             median    stddev
# spearman  0.772228  0.007143
# pearson   0.809142  0.010524
# MAE       3.806990  0.116615
# ===============
# model_name: RNN, exp_name: protospacer_extended
#              run_0     run_1     run_2     run_3     run_4      mean  \
# spearman  0.769832  0.778847  0.753758  0.750929  0.768922  0.764458
# pearson   0.815824  0.803886  0.780654  0.756225  0.809744  0.793267
# MAE       3.782751  3.880668  3.981464  4.264782  3.534493  3.888832
#
#             median    stddev
# spearman  0.768922  0.011762
# pearson   0.803886  0.024618
# MAE       3.880668  0.267766
# ===============
# model_name: Transformer, exp_name: protospacer
#              run_0     run_1     run_2     run_3     run_4      mean  \
# spearman  0.682484  0.703473  0.695263  0.724780  0.690616  0.699323
# pearson   0.748878  0.755179  0.741985  0.745598  0.735357  0.745399
# MAE       4.614114  4.626415  4.349097  4.427824  4.253950  4.454280
#
#             median    stddev
# spearman  0.695263  0.016133
# pearson   0.745598  0.007421
# MAE       4.427824  0.163610
# ===============
# model_name: Transformer, exp_name: protospacer_extended
#              run_0     run_1     run_2     run_3     run_4      mean  \
# spearman  0.719099  0.728455  0.721773  0.708179  0.706992  0.716899
# pearson   0.779659  0.761188  0.765637  0.732273  0.750374  0.757826
# MAE       4.266432  4.219082  4.139365  4.481317  4.076254  4.236490
#
#             median    stddev
# spearman  0.719099  0.009170
# pearson   0.761188  0.017731
# MAE       4.219082  0.155120
# ===============
